# %%
import pandas as pd

# %% [markdown]
# ### importar dados e visualizar

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ead\Desktop\BRENDA_EV

# %%
url = "datasets/scores.csv"

# %%
pd.read_csv(url)
# Out:
#           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# 11  condition_12    12       2  40-44      1.0      2.0        2.0   6-10
# ...

# %%
url = "datasets/scores.csv"
dados = pd.read_csv(url,sep =";")
dados
# Out:
#    number,days,gender,age,afftype,melanch,inpatient,edu,marriage,work,madrs1,madrs2
# 0         condition_1,11,2,35-39,2,2,2,6-10,1,2,19,19
# 1         condition_2,18,2,40-44,1,2,2,6-10,2,2,24,11
# 2         condition_3,13,1,45-49,2,2,2,6-10,2,2,24,25
# 3        condition_4,13,2,25-29,2,2,2,11-15,1,1,20,16
# 4        condition_5,13,2,50-54,2,2,2,11-15,2,2,26,26
# 5          condition_6,7,1,35-39,2,2,2,6-10,1,2,18,15
# 6       condition_7,11,1,20-24,1,NA,2,11-15,2,1,24,25
# 7        condition_8,5,2,25-29,2,NA,2,11-15,1,2,20,16
# 8        condition_9,13,2,45-49,1,NA,2,6-10,1,2,26,26
# 9         condition_10,9,2,45-49,2,2,2,6-10,1,2,28,21
# 10       condition_11,14,1,45-49,2,2,2,6-10,1,2,24,24
# 11       condition_12,12,2,40-44,1,2,2,6-10,2,2,25,21
# 12      condition_13,14,2,35-39,1,2,2,11-15,2,2,18,13
# 13       condition_14,14,1,60-64,1,2,2,6-10,2,2,28,19
# 14      condition_15,13,2,55-59,2,2,2,11-15,1,1,14,18
# 15      condition_16,16,1,45-49,2,2,2,11-15,1,2,13,17
# ...

# %%
dados.head(10)
# Out:
#   number,days,gender,age,afftype,melanch,inpatient,edu,marriage,work,madrs1,madrs2
# 0        condition_1,11,2,35-39,2,2,2,6-10,1,2,19,19
# 1        condition_2,18,2,40-44,1,2,2,6-10,2,2,24,11
# 2        condition_3,13,1,45-49,2,2,2,6-10,2,2,24,25
# 3       condition_4,13,2,25-29,2,2,2,11-15,1,1,20,16
# 4       condition_5,13,2,50-54,2,2,2,11-15,2,2,26,26
# 5         condition_6,7,1,35-39,2,2,2,6-10,1,2,18,15
# 6      condition_7,11,1,20-24,1,NA,2,11-15,2,1,24,25
# 7       condition_8,5,2,25-29,2,NA,2,11-15,1,2,20,16
# 8       condition_9,13,2,45-49,1,NA,2,6-10,1,2,26,26
# 9        condition_10,9,2,45-49,2,2,2,6-10,1,2,28,21

# %%
dados.tail(10)
# Out:
#    number,days,gender,age,afftype,melanch,inpatient,edu,marriage,work,madrs1,madrs2
# 45       control_23,13,1,20-24,NA,NA,NA, ,NA,NA,NA,NA
# 46       control_24,13,2,20-24,NA,NA,NA, ,NA,NA,NA,NA
# 47       control_25,13,1,65-69,NA,NA,NA, ,NA,NA,NA,NA
# 48       control_26,13,1,35-39,NA,NA,NA, ,NA,NA,NA,NA
# 49       control_27,13,2,50-54,NA,NA,NA, ,NA,NA,NA,NA
# 50       control_28,16,2,45-49,NA,NA,NA, ,NA,NA,NA,NA
# 51       control_29,13,2,50-54,NA,NA,NA, ,NA,NA,NA,NA
# 52        control_30,9,2,35-39,NA,NA,NA, ,NA,NA,NA,NA
# 53       control_31,13,1,20-24,NA,NA,NA, ,NA,NA,NA,NA
# 54       control_32,14,2,25-29,NA,NA,NA, ,NA,NA,NA,NA

# %% [markdown]
# ### Quantidade de linhas e colunas

# %%
dados.shape
# Out:
# (55, 1)

# %% [markdown]
# ### Quantidade de informaçoes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 1 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   number,days,gender,age,afftype,melanch,inpatient,edu,marriage,work,madrs1,madrs2  55 non-null     object
# dtypes: object(1)
# memory usage: 572.0+ bytes

# %% [markdown]
# ### Tipagem

# %%
type(url)
# Out:
# str

# %% [markdown]
# ### Explorar as diferentes colunas existentes

# %%
dados.columns
# Out:
# Index(['number,days,gender,age,afftype,melanch,inpatient,edu,marriage,work,madrs1,madrs2'], dtype='object')

# %% [markdown]
# ### Selecionar somente uma coluna

# %%
dados['edu']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ead\Desktop\BRENDA_EV\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'edu'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 dados['edu']
#
# ...

# %%
dados[['nomecoluna,nomeoutracoluna']]

# %% [markdown]
# Entrega para o gerente de projetos
# Treelo Post-it concluido
# Entrega no github
